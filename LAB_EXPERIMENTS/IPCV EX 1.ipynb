# %% [markdown]
# # Ex No 1 - Installation of Open CV & To perform the basic image handling processing operation on the image

# %%
# !pip install opencv-python matplotlib numpy
# Out:
# Requirement already satisfied: opencv-python in c:\users\91950\appdata\local\programs\python\python310\lib\site-packages (4.11.0.86)
# Requirement already satisfied: matplotlib in c:\users\91950\appdata\local\programs\python\python310\lib\site-packages (3.9.2)
# Requirement already satisfied: numpy in c:\users\91950\appdata\local\programs\python\python310\lib\site-packages (2.2.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\91950\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\91950\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\91950\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\91950\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\91950\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\91950\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\91950\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\91950\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\91950\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !python -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\91950\appdata\local\programs\python\python310\lib\site-packages (25.3)
# Collecting pip
#   Downloading pip-26.0-py3-none-any.whl.metadata (4.7 kB)
# Downloading pip-26.0-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----------------- ---------------------- 0.8/1.8 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 3.9 MB/s  0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 25.3
#     Uninstalling pip-25.3:
#       Successfully uninstalled pip-25.3
# Successfully installed pip-26.0

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Image
# %matplotlib inline

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in .\appdata\local\programs\python\python310\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in .\appdata\local\programs\python\python310\lib\site-packages (from opencv-python) (2.2.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in .\appdata\local\programs\python\python310\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in .\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in .\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in .\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in .\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in .\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in .\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in .\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in .\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
Image(filename="C:\\Users\\91950\\Downloads\\Chessboards.png")

# %%
# Reading image as gray scale
cb_img = cv2.imread("C:\\Users\\91950\\Downloads\\Chessboards.png",cv2.IMREAD_GRAYSCALE)

# Print the image data (pixel values), element of a 2D numpy array.
# Each pixel value is 8-bits [0,255]
print(cb_img)
# Out:
# [[  9  65  63 ...   6   1  27]
#  [ 33 239 249 ...  12   2  28]
#  [ 28 245 253 ...  14   1  27]
#  ...
#  [  6   8   1 ...  85   4  27]
#  [  6   7   1 ...  84   4  27]
#  [  6   8   1 ...  87   4  28]]

# %%
print("Shape of the image: ", cb_img.shape)
print("Data type of the image: ", cb_img.dtype)
print("Size of the image: ", cb_img.size)
# Out:
# Shape of the image:  (364, 367)
# Data type of the image:  uint8
# Size of the image:  133588

# %%
plt.imshow(cb_img)
plt.title("Image Display Using Matplotlib")
plt.axis("off") 
plt.show()

# %%
plt.imshow(cb_img, cmap = "gray")
plt.axis("off")
plt.show()

# %%
Image("C:\\Users\\91950\\Downloads\\Avocado .png")

# %%
# Reading the image
avacado_img = cv2.imread("C:\\Users\\91950\\Downloads\\Avocado .png",cv2.IMREAD_COLOR)

# Printing the shape of the image
print("Image shape (height, width, channels) is:", avacado_img.shape)

# Printing the size of the image
print("Image size is:", avacado_img.size)

# Printing the data-type of the image
print("Data type of image is:", avacado_img.dtype)
# Out:
# Image shape (height, width, channels) is: (394, 299, 3)
# Image size is: 353418
# Data type of image is: uint8

# %%
# Displaying the image using matplotlib
plt.imshow(avacado_img)
plt.axis("off")
plt.show()

# %%
# Reversing the channels of the color image
avacado_img_channels_reversed = avacado_img[:, :, ::-1]
plt.imshow(avacado_img_channels_reversed)
plt.axis("off")
plt.show()

# %%
# Split the image into the B,G,R components
b, g, r = cv2.split(avacado_img)
# Show the channels
plt.figure(figsize = [20, 5])
# Red Channel
plt.subplot(1, 4, 1)
plt.imshow(r, cmap = "gray")
plt.title("Red Channel")
plt.axis("off")
# Green Channel
plt.subplot(1, 4, 2)
plt.imshow(g, cmap = "gray")
plt.title("Green Channel")
plt.axis("off")
# Blue Channel
plt.subplot(1, 4, 3)
plt.imshow(b, cmap = "gray")
plt.title("Blue Channel")
plt.axis("off")
# Merge the individual channels into a BGR image
merged_img = cv2.merge((b, g, r))
# Show the merged output
plt.subplot(1, 4, 4)
plt.imshow(merged_img[:, :, ::-1])
plt.title("Merged Output")
plt.axis("off")
plt.show()

# %%
# OpenCV stores color channels in a different order than most other applications

avacado_img_bgr = cv2.imread("C:\\Users\\91950\\Downloads\\Avocado .png",cv2.IMREAD_COLOR)

# Converting BGR to RGB
avacado_img_rgb = cv2.cvtColor(avacado_img_bgr, cv2.COLOR_BGR2RGB)

plt.imshow(avacado_img_rgb)
plt.title("BGR to RGB")
plt.axis("off")
plt.show()

# %%
# Converting to HSV
avacado_img_hsv = cv2.cvtColor(avacado_img_bgr, cv2.COLOR_BGR2HSV)
# Split the image into H, S, V components
h, s, v = cv2.split(avacado_img_hsv)
# Show the channels
plt.figure(figsize = [20, 5])
# Hue Channel
plt.subplot(1, 4, 1)
plt.imshow(h, cmap = "gray")
plt.title("H Channel")
plt.axis("off")
# Saturation Channel
plt.subplot(1, 4, 2)
plt.imshow(s, cmap = "gray")
plt.title("S Channel")
plt.axis("off")
# Value Channel
plt.subplot(1, 4, 3)
plt.imshow(v, cmap = "gray")
plt.title("V Channel")
plt.axis("off")
# Show the original image
plt.subplot(1, 4, 4)
plt.imshow(avacado_img_rgb)
plt.title("Original")
plt.axis("off")
plt.show()

# %%
# Converting BGR to grayscale
avacado_img_gray = cv2.cvtColor(avacado_img_bgr, cv2.COLOR_BGR2GRAY)
plt.imshow(avacado_img_gray, cmap = "gray")
plt.title("BGR to grayscale")
plt.axis("off")
plt.show()

# %%
h_new = h + 30
avacado_img_merged = cv2.merge((h_new, s, v))
avacado_img_rgb = cv2.cvtColor(avacado_img_merged, cv2.COLOR_HSV2RGB)
# Split the image into the B,G,R components
h,s,v = cv2.split(avacado_img_merged)
# Show the channels
plt.figure(figsize = [20, 5])
# Hue Channel
plt.subplot(1, 4, 1)
plt.imshow(h, cmap = "gray")
plt.title("H + 30 Channel")
plt.axis("off")
# Saturation Channel
plt.subplot(1, 4, 2)
plt.imshow(s, cmap = "gray")
plt.title("S Channel")
plt.axis("off")
# Value Channel
plt.subplot(1, 4, 3)
plt.imshow(v, cmap = "gray")
plt.title("V Channel")
plt.axis("off")
# Show the original image
plt.subplot(1, 4, 4)
plt.imshow(avacado_img_rgb)
plt.title("Merged Image")
plt.axis("off")
plt.show()

# %%
# Saving the image
cv2.imwrite("avacado_saved.jpg", avacado_img_rgb)
# Out:
# True
